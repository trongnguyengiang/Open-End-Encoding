# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import os
import re
import numpy as np
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/giangtrongnguyen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/giangtrongnguyen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# INPUTTING THE FILES

# %% [markdown]
# This set of code aims to encode the open-end responses from the "data" sheet by using the codebook of each question, in this case is "CodebookQ3" and "CodebookQ5"

# %%
input_path=r"/Users/giangtrongnguyen/Python/Portfolio/OE_Encoding/SantaClara_Survey.xlsx"
other_code=98

codebook1 = pd.read_excel(input_path, sheet_name='CodebookQ3')
codebook2 = pd.read_excel(input_path, sheet_name='CodebookQ5')
# codebook3 = pd.read_excel(input_path, sheet_name='codebookQ47')
# codebook4 = pd.read_excel(input_path, sheet_name='Codebook')
# codebook5 = pd.read_excel(input_path, sheet_name='Codebook')
# codebook6 = pd.read_excel(input_path, sheet_name='Codebook')

codebooks={'codebook1': codebook1,
 'codebook2': codebook2,
# 'codebook3': codebook3,
 # 'codebook4': codebook4,
 # 'codebook5': codebook5,
 # 'codebook6': codebook6,
 }
data = pd.read_excel(input_path, sheet_name='data')

# %% [markdown]
# Here is how the "data" sheet looks like

# %%
data
# Out:
#      id       token                                                 Q3  \
# 0     1  2482ae9ae6  Crime has increased significantly in my neighb...
# 1     2  79979fd5c5     Limited mental health services. It's expensive
# 2     3  b928bd5d25                            Expensive healthcare!!!
# 3     4  5e50ef0bde                            Housing price is stupid
# 4     5  c18365046b                           You can not manage waste
# ..  ...         ...                                                ...
# 95   96  a1bb8f08da                     Public transport is unreliable
# 96   97  b194f43891  Water shortages??? Why you turn them off so often
# 97   98  56eac40abe                  Crime has increased significantly
# 98   99  af5f006fa9                                        Lack of job
# 99  100  8bca5e17bc            Gentrification and expensive healthcare
#
#                                                    Q5
# 0   I support Trump's stance on immigration and bo...
# 1   He improved the job market significantly durin...
# 2     His tax reforms helped small businesses thrive.
# 3   I don’t like how he handled the COVID-19 pande...
# 4   Trump was too confrontational with foreign all...
# ..                                                ...
# 95     He mobilized a significant political movement.
# 96    Trump often contradicted his own team publicly.
# 97         He turned press briefings into spectacles.
# 98    His legacy is one of polarization and upheaval.
# 99     He changed how Americans view truth and facts.
#
# [100 rows x 4 columns]

# %% [markdown]
# Here is how the "CodebookQ3" and "CodebookQ5" look like
# Q3. What do you think are critical issue the City of Santa Clara is facing?
# Q5. What topics come to mind when you think of Donald Trump?

# %%
#codebookQ3
codebook1
# Out:
#     Code                                     Description
# 0      1                           Housing affordability
# 1      2                          Traffic and congestion
# 2      3                    Public transportation issues
# 3      4                                    Homelessness
# 4      5           Environment/ Green space/ Air quality
# 5      6                                Crime and safety
# 6      7                    Development/ Overdevelopment
# 7      8                 Water/ Waste/  Utility concerns
# 8      9                     Education system/ Schooling
# 9     10  Healthcare accessibility/Mental health service
# 10    11                                    Economy/ Job
# 11    98                                           Other

# %%
#codebookQ5
codebook2
# Out:
#     Code                                        Description
# 0      1  Economy / Jobs / Tax reform / Deregulation/ Ma...
# 1      2  Border control / Immigration / National securi...
# 2      3    Trade deals / Rural focus / Conservative values
# 3      4  Neutral / Mixed views / Balanced opinion / Pol...
# 4      5  COVID handling / Padenmic/ Isolationism / Publ...
# 5      6  Aggressive rhetoric / Inappropriate behavior /...
# 6      7  Social media / Tweets / Press briefings / Ente...
# 7      8  Misinformation / Conspiracy / Election denial ...
# 8      9  Undermining institutions / Disregard norms / C...
# 9     10  Climate policy / Religion in politics / Health...
# 10    98                                              Other

# %% [markdown]
# TEXT CLEANING FUNCTION. This function is to:
# - Split the response into a list of separate words
# - Remove the stop words in the response
# - Remove the special character in the response
# - Combine the separate words into a cleaned sentence

# %%
def clean_stop_word(x):
   if pd.isna(x):
      return ""
   a = re.sub(r"[^a-zA-Z\s]", "", str(x)).lower()
   stop_words = set(stopwords.words('english'))
   word_tokens = word_tokenize(a)
   filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words and re.search(r'\w', w)]
   return ' '.join(filtered_sentence)

# %% [markdown]
# TEXT STEMMING FUNCTION.
# This function is to stem the text, convert the vocabularies in the same word family into the same format. For example: "educate", "education", "educational" will be all converted to "educ"

# %%
# STEMMING FUNCTION
stemmer = PorterStemmer()
def stem_text(text):
   if pd.isna(text):
      return set()
   words = word_tokenize(str(text).lower())
   return [stemmer.stem(word) for word in words]

# %% [markdown]
# CREATING CODED COLUMNS, APPLYING TEXT CLEANING & STEMMING FUNCTIONS

# %%
oe_questions=[]
cloned_oe_questions=[]

for i, col_name in enumerate(list(data.columns)):
   if i>=2:
      oe_questions.append(col_name)
      data[f"{col_name}x"] = data[col_name]
      cloned_oe_questions.append(f"{col_name}x")
      data[f"{col_name}x"]= data[f"{col_name}x"].apply(clean_stop_word)

      for j in range(3,0,-1):
         add_col=f"{col_name}x_Coded{j}"
         data.insert(data.columns.get_loc(col_name)+1, add_col, np.nan)

# %% [markdown]
# JUST SOME DISCLAIMER TO INTERACT WITH THE USERS

# %%
print()
print('Hi there! Thank you for choosing me! Please bare in mind that I myself can not replace human work completely for OE coding. You MUST recheck the final result before submit the official data')
print('The process may take some time, let have your eyes rested a bit!!!\n')
# Out:
# Hi there! Thank you for choosing me! Please bare in mind that I myself can not replace human work completely for OE coding. You MUST recheck the final result before submit the official data
# The process may take some time, let have your eyes rested a bit!!!

# %%
# CODING OE
for idx, a in enumerate(cloned_oe_questions): # This loop goes through each question that need coding
    print(f'Working on {a.replace("x","")}...') 
    codebook = codebooks[str('codebook'+str(idx+1))] 
    for i in range(len(data)): # This loop goes through each response
        answer_words = stem_text(data.loc[i, a]) 
        used_codes = set()

        for m in answer_words: # This loop goes through each word in the responses
            for j in range(len(codebook)): # This loop goes through the codebook
                for col in[str(a+'_Coded1'), str(a+'_Coded2'), str(a+'_Coded3')]: # This loop goes through coded column 1 - 2 - 3
                    
                    code = codebook.loc[j, 'Code'] # Get the code from the codebook

                    if not answer_words: # If the response is empty, skip to the next iteration
                        data.loc[i, col]=np.nan
                        continue
                   
                    if (codebook.loc[j, 'Code'] == other_code) or (code in used_codes) or (not pd.isna(data.loc[i, col])): # Skip to the next iteration if the code is 'other_code', or if the code has been used, or if the column is already filled
                        continue

                    # APPLYING CLEANING & STEMMING FUNCTION FOR THE CODEBOOKS
                    keywords = [clean_stop_word(kw.lower().strip()) for kw in str(codebook.loc[j, 'Description']).split("/")] 
                    keywords = [i for kw in keywords for i in word_tokenize(kw)]
                    keyword_stems = [stemmer.stem(kw) for kw in keywords]
 
                    if m in keyword_stems: # If the word in the response matches the word of the current code in the codebook, encode it
                        data.loc[i, col] = codebook.loc[j, 'Code']
                        used_codes.add(code)
                        break

        if pd.isna(data.loc[i, str(a+'_Coded1')]) and answer_words: # If the first coded column is still empty and the response is not empty, fill it with 'other_code'
            data.loc[i, str(a+'_Coded1')] = other_code
    print(f'Finish {a.replace("x","")}!\n')
# Out:
# Working on Q3...
# Finish Q3!
#
# Working on Q5...
# Finish Q5!

# %% [markdown]
# FORMATING & EXPORT FINAL DATA

# %%
data.drop(columns=cloned_oe_questions, inplace=True)

for i in data.columns:
    data.rename(columns=lambda i: i.replace("x",""), inplace=True)

folder_path = os.path.dirname(input_path)
output_path = os.path.join(folder_path, "OE-coded result.xlsx")

data.to_excel(output_path, index=False)

print(f"The coding process is done, you now may check your file at {output_path}")
# Out:
# The coding process is done, you now may check your file at /Users/giangtrongnguyen/Python/Portfolio/OE_Encoding/OE-coded result.xlsx

# %% [markdown]
# The encoded data will look like this

# %%
data.head(20)
# Out:
#     id       token                                                 Q3  \
# 0    1  2482ae9ae6  Crime has increased significantly in my neighb...
# 1    2  79979fd5c5     Limited mental health services. It's expensive
# 2    3  b928bd5d25                            Expensive healthcare!!!
# 3    4  5e50ef0bde                            Housing price is stupid
# 4    5  c18365046b                           You can not manage waste
# 5    6  f1957267db     Gentrification pushing out locals and homeless
# 6    7  977041adcb                      Housing is damn too expensive
# 7    8  c95444f125                      Homeless people on the street
# 8    9  354f4032b6                                Overcrowded schools
# 9   10  6b4303a90a  Noise pollution from highways the traffic are ...
# 10  11  208ae78d36                          Water shortages urgent!!!
# 11  12  c9862c6bdd                          Traffic congestion is bad
# 12  13  fabaaa738f                         We don't have enough water
# 13  14  a6fc19445b                            Public transport is bad
# 14  15  779a3bedd1                  Public transport is unreliable!!!
# 15  16  00eee0dbf7  Gentrification pushing out locals and we are n...
# 16  17  18fa41ea65                       Public transport is damn bad
# 17  18  81a2443a29      Limited mental health services. I'm depressed
# 18  19  7b2369136f                               Air quality is gross
# 19  20  f19d3786bb                                 Air quality is bad
#
#     Q3_Coded1  Q3_Coded2  Q3_Coded3  \
# 0         6.0        NaN        NaN
# 1        10.0        NaN        NaN
# 2        10.0        NaN        NaN
# 3         1.0        NaN        NaN
# 4         8.0        NaN        NaN
# 5         4.0        NaN        NaN
# 6         1.0        NaN        NaN
# 7         4.0        NaN        NaN
# 8         9.0        NaN        NaN
# 9         2.0        NaN        NaN
# 10        8.0        NaN        NaN
# 11        2.0        NaN        NaN
# 12        8.0        NaN        NaN
# 13        3.0        NaN        NaN
# 14        3.0        NaN        NaN
# 15        8.0        NaN        NaN
# 16        3.0        NaN        NaN
# 17       10.0        NaN        NaN
# 18        5.0        NaN        NaN
# 19        5.0        NaN        NaN
#
#                                                    Q5  Q5_Coded1  Q5_Coded2  \
# 0   I support Trump's stance on immigration and bo...        2.0        NaN
# 1   He improved the job market significantly durin...        1.0        NaN
# 2     His tax reforms helped small businesses thrive.        1.0        NaN
# 3   I don’t like how he handled the COVID-19 pande...        5.0        NaN
# 4   Trump was too confrontational with foreign all...       98.0        NaN
# 5   His speech style is too aggressive for a presi...        6.0        NaN
# 6          He resonates with working-class Americans.       98.0        NaN
# 7            His environmental policies were harmful.       10.0        NaN
# 8           He speaks plainly, which appeals to many.       98.0        NaN
# 9     Trump made the Supreme Court more conservative.        3.0        NaN
# 10               He focused too much on social media.        7.0        NaN
# 11           I appreciate his focus on law and order.        3.0        NaN
# 12           Trump disrespected democratic processes.       98.0        NaN
# 13     He brought attention to neglected rural areas.        3.0        NaN
# 14  He did not denounce extremist groups strongly ...        8.0        NaN
# 15            His foreign policies were isolationist.       10.0        NaN
# 16                  He strengthened military funding.        2.0        NaN
# 17              Trump’s approach divided the country.       98.0        NaN
# 18                      He prioritized American jobs.        1.0        NaN
# 19            He failed to support healthcare reform.       10.0        1.0
#
#     Q5_Coded3
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN

# %%
#Codebook for Q3
codebook1
# Out:
#     Code                                     Description
# 0      1                           Housing affordability
# 1      2                          Traffic and congestion
# 2      3                    Public transportation issues
# 3      4                                    Homelessness
# 4      5           Environment/ Green space/ Air quality
# 5      6                                Crime and safety
# 6      7                    Development/ Overdevelopment
# 7      8                 Water/ Waste/  Utility concerns
# 8      9                     Education system/ Schooling
# 9     10  Healthcare accessibility/Mental health service
# 10    11                                    Economy/ Job
# 11    98                                           Other

# %%
#Codebook for Q45
codebook2
# Out:
#     Code                                        Description
# 0      1  Economy / Jobs / Tax reform / Deregulation/ Ma...
# 1      2  Border control / Immigration / National securi...
# 2      3    Trade deals / Rural focus / Conservative values
# 3      4  Neutral / Mixed views / Balanced opinion / Pol...
# 4      5  COVID handling / Padenmic/ Isolationism / Publ...
# 5      6  Aggressive rhetoric / Inappropriate behavior /...
# 6      7  Social media / Tweets / Press briefings / Ente...
# 7      8  Misinformation / Conspiracy / Election denial ...
# 8      9  Undermining institutions / Disregard norms / C...
# 9     10  Climate policy / Religion in politics / Health...
# 10    98                                              Other

# %% [markdown]
# This set of code can help us shorten the process of OE coding, however, can not completely replace human work as these task require human intuition to define the tone and mood of the response. It can work well with responses that contain specific words in the codebook but with the responses that mention general ideas or relevant words but not the same word family in the codebook, it can not encode them properly

# %% [markdown]
# For example, in Q3, there are some responses can be encoded as code 5 ("Environment/ Green space/ Air quality") but this set of code could not recognize it

# %%
data.loc[data['Q3_Coded1']==other_code, 'id':'Q3_Coded3']
# Out:
#     id       token                                                 Q3  \
# 29  30  1dce9308aa                      Noise pollution from highways
# 32  33  42e4d2d841           Climate change impact is visible you see
# 34  35  75c14253fe  Climate change impact is visible. They are doi...
# 59  60  51838f5555                        Gentrification and I'm poor
# 70  71  d217ab58af          Climate change impact is visible for sure
# 81  82  7760fd6a8e  Climate change impact is visible nobody do any...
# 86  87  16382b52ed          Climate change impact is for sure visible
# 89  90  d48c82ece7                   Climate change impact is visible
#
#     Q3_Coded1  Q3_Coded2  Q3_Coded3
# 29       98.0        NaN        NaN
# 32       98.0        NaN        NaN
# 34       98.0        NaN        NaN
# 59       98.0        NaN        NaN
# 70       98.0        NaN        NaN
# 81       98.0        NaN        NaN
# 86       98.0        NaN        NaN
# 89       98.0        NaN        NaN

# %% [markdown]
# In Q5, a lot of responses could be encoded but the responses and the codebook do not share the same word family, therefore they are skipped

# %%
data.loc[data['Q5_Coded1']==other_code, ['id','token', 'Q5', 'Q5_Coded1', 'Q5_Coded2', 'Q5_Coded3']]
# Out:
#     id       token                                                 Q5  \
# 4    5  c18365046b  Trump was too confrontational with foreign all...
# 6    7  977041adcb         He resonates with working-class Americans.
# 8    9  354f4032b6          He speaks plainly, which appeals to many.
# 12  13  fabaaa738f           Trump disrespected democratic processes.
# 17  18  81a2443a29              Trump’s approach divided the country.
# 23  24  81a0c47b20                       He misused executive powers.
# 25  26  fefd9825d3                    He cut unnecessary regulations.
# 32  33  42e4d2d841                     He reduced global cooperation.
# 34  35  75c14253fe             He appealed to nationalist sentiments.
# 36  37  3d35c3472e       He was loyal to his base, not all Americans.
# 37  38  df7f099130           He emphasized personal loyalty too much.
# 38  39  4e3cd3b44b               He broadened the ideological divide.
# 41  42  39c417053e         He lacked compassion in crisis situations.
# 43  44  624818680d                  He was consistent in his beliefs.
# 44  45  77c9c9eb81               His administration lacked diversity.
# 46  47  e33fdf4465            He appealed to fears rather than unity.
# 48  49  560578e49c                  He left a legacy of polarization.
# 52  53  06fd6fd50c  I believe he cared more about ratings than gov...
# 54  55  4504fb71f7  He lacked the diplomacy expected from a world ...
# 56  57  7b6411c010  He focused too much on personal loyalty in his...
# 58  59  02f4a8ce83  He used fear tactics rather than unifying mess...
# 61  62  69ebf5892f  He politicized the pandemic instead of followi...
# 64  65  29bf335a52  His supporters felt heard, even if others felt...
# 70  71  d217ab58af  He gave a voice to people who felt ignored by ...
# 71  72  2d1cefa38e         He minimized threats like white supremacy.
# 72  73  49b48dba98  Trump’s base remained fiercely loyal despite c...
# 75  76  e1adf3dd56       His approach emboldened far-right extremism.
# 76  77  cd88191067  Trump managed to shift the Republican Party's ...
# 77  78  d4521c7706   He thrived on controversy rather than consensus.
# 84  85  1c590cc88a  Trump’s presidency exposed weaknesses in Ameri...
# 85  86  6e536cdca7  He was unapologetically himself, for better or...
# 86  87  16382b52ed  His legal issues became a distraction from gov...
# 87  88  3a0b83757c        He altered how candidates campaign forever.
# 88  89  2ed9414ec0  He ruled through executive orders rather than ...
# 90  91  a8c34ae878   He created a culture of loyalty over competence.
# 96  97  b194f43891    Trump often contradicted his own team publicly.
# 98  99  af5f006fa9    His legacy is one of polarization and upheaval.
#
#     Q5_Coded1  Q5_Coded2  Q5_Coded3
# 4        98.0        NaN        NaN
# 6        98.0        NaN        NaN
# 8        98.0        NaN        NaN
# 12       98.0        NaN        NaN
# 17       98.0        NaN        NaN
# 23       98.0        NaN        NaN
# 25       98.0        NaN        NaN
# 32       98.0        NaN        NaN
# 34       98.0        NaN        NaN
# 36       98.0        NaN        NaN
# 37       98.0        NaN        NaN
# 38       98.0        NaN        NaN
# 41       98.0        NaN        NaN
# 43       98.0        NaN        NaN
# 44       98.0        NaN        NaN
# 46       98.0        NaN        NaN
# 48       98.0        NaN        NaN
# 52       98.0        NaN        NaN
# 54       98.0        NaN        NaN
# 56       98.0        NaN        NaN
# 58       98.0        NaN        NaN
# 61       98.0        NaN        NaN
# 64       98.0        NaN        NaN
# 70       98.0        NaN        NaN
# 71       98.0        NaN        NaN
# 72       98.0        NaN        NaN
# 75       98.0        NaN        NaN
# 76       98.0        NaN        NaN
# 77       98.0        NaN        NaN
# 84       98.0        NaN        NaN
# 85       98.0        NaN        NaN
# 86       98.0        NaN        NaN
# 87       98.0        NaN        NaN
# 88       98.0        NaN        NaN
# 90       98.0        NaN        NaN
# 96       98.0        NaN        NaN
# 98       98.0        NaN        NaN

# %% [markdown]
# With this Stemming method, the codebooks need to cover as many keywords that appear in the responses as many as possible. Human quality check is also demanded to minimize the mistakes. However, comparing to manual encoding, it could help to save a plenty of time
